# %%
class Vector():
    def __init__(self,x,y,z):
        self.x = x
        self.y = y
        self.z = z

    def __repr__(self): #print() 정의
        return '(%s,%s,%s)'%(self.x,self.y,self.z) #print() -> (x,y,z)

    def __add__(self,other): # +연산 정의
        return Vector(self.x+other.x,self.y+other.y,self.z+other.z)
    __radd__ = __add__

    def __mul__(self,other): #벡터 내적 정의
        #여기에 코드 입력

        pass
    __rmul__ = __mul__

# %%
'''
Q.1 벡터 클래스 만들기

위의 코드는 벡터(Vector)를 위한 클래스를 일부 만들어 본 것입니다.
위에서부터 아래의 코드를 실행하면 print와 덧셈 연산이 정의가 된 것을 볼 수 있을 것입니다.

그럼 이번에는 벡터의 내적을 정의해봅시다. 내적을 곱하기 연산으로 나타내어 보는 것이죠.
위 코드의 __mul__메서드를 완성해서 아래 코드 a*b의 결과가 두 벡터 a,b의 내적이 되게 해 보세요.
'''

# %%
a = Vector(1,1,1)
b = Vector(2,2,2)

print(a)
print(a+b)
print(a*b)
# Out:
# (1,1,1)
# (3,3,3)
# None

# %%
'''
Q.2 이상 기체 상태 방정식

PV = nRT라는 식을 본 적 있을 겁니다. 이 식에 따르면 부피와 압력은 서로 반비례하는 관계를 가지죠.
이 과제의 파일과 함께 올라온 IdealGasPV.txt라는 파일은 시뮬레이션으로 이상기체의 부피와 압력을 구한 자료입니다.
이 자료의 수치들을 불러와서 부피와 압력의 그래프를 그려보세요.

*참고: 문자열을 특정 문자로 분리해서 리스트로 만드려면,
예를 들어 'Hello World'를 ['Hello','World']로 만드려면 문자열.split(나눌 문자)를 이용하세요.
위의 예를 사용하면 'Hello World'.split(' ')가 되겠죠.
'''

# %%
import matplotlib.pyplot as plt

#여기에 코드 입력

# %%
'''
Q.3 Full Width Half Max (반치폭)

Full Width Half Max, 줄여서 FWHM이란 신호(함수)의 최댓값의 절반 값에서의 폭을 뜻합니다. (자세한 것은 인터넷을 찾아보세요)

자주 사용되는 분포함수중 하나로 sech(Hyperbolic Secant)함수가 있는데요,
f(x)=sech(x/A)의 FWHM는 2A*ln(2+루트3)으로 구할 수 있습니다.

그렇다면, 실제로 sech(x/A)의 FWHM가 정말 그러한 값이 맞는지 실제로 구해서 비교해 보세요.
한번은 그래프에서 FWHM를 구해보고 한번은 2A*ln(2+루트3)의 값을 구해보면 알 수 있을 것입니다.
'''

# %%
import numpy as np

x = np.linspace(-10,10,200)
A = 3
y = 1/np.cosh(x/A)

plt.plot(x,y)
plt.show()

# %%
#여기에 코드 입력
